# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahFeanor/Portfolio-DataScience/blob/main/Analise_Covid-19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <sub> 📂 **Projetos | Data Science | Por Sarah Faria Rezende** </sub>
#
# ---

# %% [markdown]
# # **Panorama Global do Coronavírus** 🔬🌍
#
# A **COVID-19** representa a enfermidade ocasionada por um coronavírus chamado **SARS-CoV-2**. Em 31 de dezembro de 2019, a Organização Mundial da Saúde (OMS) obteve informações sobre o vírus, após ser notificada acerca de um agrupamento de casos de "pneumonia viral" na cidade de Wuhan, localizada na República Popular da China. Esse vírus se propaga principalmente por meio de partículas expelidas ao tossir ou espirrar por indivíduos contaminados, e a intensidade dos sintomas manifestados varia consideravelmente de pessoa para pessoa.

# %% [markdown]
# ![capa-hub-covid-2020.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Foram adotadas várias medidas com o intuito de conter a disseminação da enfermidade, incluindo o fechamento de estabelecimentos laborais e a suspensão ou redução de atividades. Constata-se que cerca de 80% dos casos confirmados são de caráter assintomático e de duração breve. A maioria dos indivíduos enquadrados nesse segmento se recupera completamente, sem quaisquer efeitos duradouros.
#
# Contudo, aproximadamente 15% dos indivíduos enfrentarão quadros infecciosos graves, demandando suplementação de oxigênio. Os restantes 5% da população, que corresponde a uma parcela menor, serão diagnosticados com infecções extremamente severas, requerendo assistência ventilatória mediante o uso de aparelhos respiratórios mecânicos em um contexto hospitalar.
#
# ## 📍 **Objetivo**
#
# O escopo deste projeto, por conseguinte, está em aprimorar a conscientização contextual referente à COVID-19 no Brasil. Para isso, serão analisados dados de domínio público relativos à enfermidade.

# %% [markdown]
# ## 📂 **Aquisição dos Dados**
# As informações empregadas são acessíveis através de um repositório no [GitHub](https://github.com/owid/covid-19-data/tree/master/public/data) e têm origem no[ Our World in Data](https://ourworldindata.org/coronavirus) (OWID), uma plataforma científica online voltada para a análise de questões globais prementes, tais como pobreza, doenças, fome, mudanças climáticas, conflitos, riscos existenciais e disparidades.

# %% [markdown]
# ## 🔍 **Análise dos Dados**
#
# Esta etapa tem por objetivo permitir um entendimento de como os dados estão estruturados.
#
# ### **Dicionário das variáveis**
#
# * `aged_65_older`: Parcela da população com 65 anos ou mais, ano mais recente disponível
# * `aged_70_older`: Parcela da população com 70 anos ou mais em 2015
# * `cardiovasc_death_rate`: Taxa de mortalidade por doença cardiovascular em 2017 (número anual de mortes por 100.000 pessoas)
# * `continent`: Continente da localização geográfica
# * `date`: Data da observação
# * `diabetes_prevalence`: Prevalência de diabetes (% da população de 20 a 79 anos) em 2017
# * `extreme_poverty`: Percentual da população que vive em extrema pobreza, ano mais recente disponível desde 2010
# * `female_smokers`: Proporção de mulheres que fumam, ano mais recente disponível
# * `gdp_per_capita`: Produto interno bruto em paridade de poder de compra (dólares internacionais constantes de 2011), ano mais recente disponível
# * `handwashing_facilities`: Percentagem da população com instalações básicas de lavagem das mãos nas instalações, ano mais recente disponível
# * `hospital_beds_per_thousand`: Camas hospitalares por 1.000 pessoas, ano mais recente disponível desde 2010
# * `hosp_patients`: Número de pacientes com COVID-19 no hospital em um determinado dia
# * `hosp_patients_per_million`: Número de pacientes com COVID-19 no hospital em um determinado dia por 1.000.000 de pessoas
# * `human_development_index`: Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano – uma vida longa e saudável, conhecimento e um padrão de vida decente.
# * `icu_patients`: Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia
# * `icu_patients_per_million`: Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 de pessoas
# * `iso_code`: Código do país de três letras
# * `life_expectancy`: Expectativa de vida ao nascer em 2019
# * `location`: Localização geográfica
# * `male_smokers`: Proporção de homens que fumam, ano mais recente disponível
# * `median_age`: Idade média da população, projeção da ONU para 2020
# * `new_cases`: Novos casos confirmados de COVID-19. As contagens podem incluir casos prováveis, quando relatados.
# * `new_cases_per_million`: Novos casos confirmados de COVID-19 por 1.000.000 de pessoas. As contagens podem incluir casos prováveis, quando relatados.
# * `new_cases_smoothed`: Novos casos confirmados de COVID-19 (suavizado de 7 dias). As contagens podem incluir casos prováveis, quando relatados.
# * `new_cases_smoothed_per_million`: Novos casos confirmados de COVID-19 (suavizado em 7 dias) por 1.000.000 de pessoas. As contagens podem incluir casos prováveis, quando relatados.
# * `new_deaths`: Novas mortes atribuídas ao COVID-19. As contagens podem incluir mortes prováveis, quando relatadas.
# * `new_deaths_per_million`: Novas mortes atribuídas ao COVID-19 por 1.000.000 de pessoas. As contagens podem incluir mortes prováveis, quando relatadas.
# * `new_deaths_smoothed`: Novas mortes atribuídas ao COVID-19 (suavizado de 7 dias). As contagens podem incluir mortes prováveis, quando relatadas.
# * `new_deaths_smoothed_per_million`: Novas mortes atribuídas ao COVID-19 (suavizado de 7 dias) por 1.000.000 de pessoas. As contagens podem incluir mortes prováveis, quando relatadas.
# * `new_people_vaccinated_smoothed`: Número diário de pessoas que recebem sua primeira dose de vacina (suavizado de 7 dias)
# * `new_people_vaccinated_smoothed_per_hundred`: Número diário de pessoas que recebem sua primeira dose de vacina (suavizado de 7 dias) por 100 pessoas na população total
# * `new_tests`: Novos testes para COVID-19 (calculado apenas para dias consecutivos)
# * `new_tests_per_thousand`: Novos testes para COVID-19 por 1.000 pessoas
# * `new_tests_smoothed`: Novos testes para COVID-19 (suavizado de 7 dias). Para países que não relatam dados de teste diariamente, assumimos que os testes mudaram igualmente diariamente em todos os períodos em que nenhum dado foi relatado. Isso produz uma série completa de números diários, que são então calculados em uma janela contínua de 7 dias
# * `new_tests_smoothed_per_thousand`: Novos testes para COVID-19 (suavizado de 7 dias) por 1.000 pessoas
# * `new_vaccinations`: Novas doses de vacinação COVID-19 administradas (calculadas apenas para dias consecutivos)
# * `new_vaccinations_smoothed`: Novas doses de vacinação COVID-19 administradas (suavizado por 7 dias). Para países que não relatam dados de vacinação diariamente, assumimos que a vacinação mudou igualmente diariamente em todos os períodos em que nenhum dado foi relatado. Isso produz uma série completa de números diários, que são então calculados em uma janela contínua de 7 dias
# * `new_vaccinations_smoothed_per_million`: Novas doses de vacinação COVID-19 administradas (suavizadas em 7 dias) por 1.000.000 de pessoas na população total
# * `new_vaccinations_smoothed_per_thousand`: Novas doses de vacinação

# %% [markdown]
# ## **Importando os pacotes necessários**

# %%
# Importando as biblioteca necessárias

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import math
from scipy import stats

# %matplotlib inline
# tamanho dos gráficos
plt.rcParams['figure.figsize'] = [10,5]
# tamanho dos dados
plt.rcParams['font.size'] = 12
# tamanho das coluna a exibir os dados
pd.set_option('display.max_rows', 67)

# %% [markdown]
# ## **Importando os Dados Necessários**

# %%
# importar o dataframe em csv
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %% [markdown]
# ## **Análise dos Dados**
#
# Nesta etapa de **análise exploratória** dos dados, vamos realizar uma **explanação inicial das variáveis** contidas no conjunto de dados. Iremos **examinar** informações relacionadas a casos da *doença*, *vacinação*,* mortes* e outras métricas relevantes. Além disso, vamos buscar responder às seguintes questões:
#
# 1. *Quais são os cinco países com o maior número de casos de COVID-19?*
# 2. *Quais são os cinco países com o maior número de mortes registradas?*
# 3. *Quais são os cinco países com o maior número de pessoas vacinadas?*
# 4. *Existe alguma correlação entre a parcela da população com mais de 65 anos e o percentual de mortes?*
# 5. *Existe alguma correlação entre o Produto Interno Bruto (PIB) de um país e o número total de mortes? *
#
# ## **Análise Exploratória Global**
#
# Para começar, vamos visualizar as primeiras cinco entradas do conjunto de dados."

# %%
# Visualizar o tamanho do dataframe
print("Entradas: ", df.shape[0])
print("Variáveis: ", df.shape[1])
# Out:
# Entradas:  334221
# Variáveis:  67

# %%
# Visualizar as 5 primeiras entradas
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# Extrair o tipo das variáveis
df.dtypes
# Out:
# iso_code                                       object
# continent                                      object
# location                                       object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# reproduction_rate                             float64
# ...

# %%
# Extrair o nome das colunas
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
# Porcentagem de itens nulos
(df.isnull().sum()/df.shape[0]).sort_values(ascending = True) * 100
# Out:
# iso_code                                       0.000000
# population                                     0.000000
# location                                       0.000000
# date                                           0.000000
# new_deaths_per_million                         2.707191
# new_deaths                                     2.707191
# new_cases                                      2.723348
# new_cases_per_million                          2.723348
# new_deaths_smoothed_per_million                3.075211
# new_deaths_smoothed                            3.075211
# new_cases_smoothed_per_million                 3.100045
# new_cases_smoothed                             3.100045
# continent                                      4.748954
# life_expectancy                                8.017749
# total_cases                                   11.221617
# total_cases_per_million                       11.221617
# population_density                            15.124723
# ...

# %% [markdown]
# 🔷 Após a obtenção dos resultados, podemos observar a proporção de valores ausentes, uma vez que dividimos a soma desses valores pelo número total de linhas no conjunto de dados. Notamos também que várias variáveis contêm valores faltantes (NaN - Not a Number), com algumas delas excedendo 90%.
#
# * Vamos agora analisar as possíveis razões por trás desses valores ausentes, começando pela análise das variáveis relacionadas a `"excess_mortality": "excess_mortality_cumulative", "excess_mortality_cumulative_absolute" e "excess_mortality_cumulative_per_million".`
#
# 🔷 O termo "excesso de mortalidade" é comumente usado em epidemiologia e saúde pública para se referir ao número de óbitos de todas as causas durante um período de crise que ultrapassa o que seria esperado em condições normais. No contexto da base de dados em questão, **nosso interesse reside em entender como o número de óbitos durante a pandemia de COVID-19 se compara aos óbitos que teríamos esperado caso a pandemia não tivesse ocorrido**. Essa quantidade não pode ser conhecida precisamente, mas pode ser estimada de diferentes maneiras. Essa métrica engloba não somente óbitos confirmados por COVID-19, mas também óbitos relacionados à doença que não foram diagnosticados e reportados devidamente, além de óbitos causados por outras condições agravadas pelo cenário de crise.
#
# As razões subjacentes para a presença de valores ausentes nessas variáveis são, principalmente, as seguintes:
#
# 1. **Dificuldades de Registro e Notificação:** Nem todos os países possuem a infraestrutura e a capacidade necessárias para registrar e notificar todos os óbitos. Em nações mais desenvolvidas com sistemas de notificação de mortalidade bem estabelecidos, quase a totalidade dos óbitos é registrada. Por outro lado, em diversos países de renda média e baixa, a subnotificação de óbitos é um desafio significativo. Estima-se que, em situações normais, somente cerca de dois terços dos países registram ao menos 90% dos óbitos ocorridos, havendo casos em que menos de 50% (ou até menos de 10%) são registrados. Durante uma pandemia, essa cobertura efetiva pode ser ainda menor.
#
# 2. **Atrasos na Notificação:** Há atrasos consideráveis na notificação de óbitos, tornando os dados de mortalidade provisórios e incompletos nas semanas, meses e até anos após a ocorrência do óbito. Mesmo em países mais desenvolvidos com sistemas de notificação robustos, a extensão do atraso varia consideravelmente. Em alguns casos, os dados mais recentes são claramente incompletos e imprecisos, devido a essa demora na notificação.
#
# Agora, prosseguiremos com a análise estatística das colunas."

# %%
# estatística descritiva das colunas
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.967160e+05  3.251190e+05        3.238600e+05  2.755070e+05
# mean   6.335774e+06  1.003229e+04        1.006882e+04  8.404379e+04
# std    3.895953e+07  1.128232e+05        9.667112e+04  4.313609e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    7.615000e+03  0.000000e+00        4.290000e-01  1.250000e+02
# 50%    6.639100e+04  3.000000e+00        2.885700e+01  1.268000e+03
# 75%    6.997922e+05  3.050000e+02        5.481430e+02  1.137300e+04
# max    7.697739e+08  8.401763e+06        6.402721e+06  6.955128e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  325173.000000        323943.000000            296716.000000
# mean       89.447144            89.781336             96528.279717
# std       627.695210           571.891264            146602.912287
# min         0.000000             0.000000                 0.000000
# ...

# %% [markdown]
# * Esses motivos também são responsáveis por termos outras variáveis com valores ausentes que estão relacionadas ao número de dados registrados. Isso engloba os demais subconjuntos, como os valores nulos em `new_cases` e as alterações no número total de casos (`total_cases`). Essas situações surgem quando há grandes correções nos dados feitas pelos governos nacionais.
#
# * Além disso, é relevante mencionar que no conjunto de dados, a data associada a uma morte pode referir-se tanto ao momento em que a morte ocorreu quanto ao momento em que foi registrada. Essa distinção varia de país para país. As contagens de óbitos por data de registro podem variar significativamente, independentemente de haver variação real nas mortes, devido a atrasos no registro ou fechamento de cartórios nos finais de semana e feriados. Também pode ocorrer que as mortes sejam registradas, mas a data da morte seja desconhecida, como é o caso da Suécia.
#
# * As datas de uma semana de relatório específica podem variar ligeiramente entre os países. Isso acontece porque os países que fornecem dados semanais têm diferentes definições para os dias de início e término da semana. Embora a maioria siga o padrão internacional ISO 8601, que define a semana de segunda a domingo, nem todos os países seguem essa convenção.
#
# * As mortes relatadas semanalmente podem não ser diretamente comparáveis às mortes relatadas mensalmente. Por exemplo, o excesso de mortalidade calculado a partir de dados mensais tende a ser menor do que o excesso calculado a partir de dados semanais.
#
# * Dado que a forma de registrar informações pode variar entre diferentes países, especialmente neste conjunto de dados, optarei por trabalhar com os dados íntegros. No entanto, transformarei a variável `date` no formato `datetime` para facilitar a manipulação dos dados.

# %%
# transformar a variável date no formato datetime
df.date = pd.to_datetime(df.date)

# %% [markdown]
# # 📍 **Quais são os países com mais casos de COVID-19?**
# Vamos analisar os dados exclusivos da variável `location`, que contém a localização do registro, a fim de identificar esses países.

# %%
# verificar os dados únicos da variável
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %% [markdown]
# Podemos observar que nem todos os registros se referem apenas a países específicos; existem também dados como '**World**', que representa o mundo inteiro, e '**High income**', que se refere a pessoas de alta renda. Além disso, há registros para continentes e outros valores. Esses dados que não são relevantes para nossa análise estão associados ao campo `iso_code`, que contém a palavra "**OWID**". Essa relação nos permite agrupar esses tipos de dados.

# %%
# verificar as cinco primeiras tuplas cujo iso_code contém 'OWID'
df.loc[df.iso_code.str.contains("OWID")].head(5)
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 1322  OWID_AFR       NaN   Africa 2020-01-03          NaN        0.0
# 1323  OWID_AFR       NaN   Africa 2020-01-04          NaN        0.0
# 1324  OWID_AFR       NaN   Africa 2020-01-05          NaN        0.0
# 1325  OWID_AFR       NaN   Africa 2020-01-06          NaN        0.0
# 1326  OWID_AFR       NaN   Africa 2020-01-07          NaN        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1322                 NaN           NaN         0.0                  NaN  ...
# 1323                 NaN           NaN         0.0                  NaN  ...
# 1324                 NaN           NaN         0.0                  NaN  ...
# 1325                 NaN           NaN         0.0                  NaN  ...
# 1326                 NaN           NaN         0.0                  NaN  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %% [markdown]
# Para dar **continuidade** à **análise** em foco e obter os *cinco países com maior número de casos*, vamos remover as entradas que correspondem a esse agrupamento específico.

# %%
# cópia do dataset
df_covid = df.copy()
# apagar tuplas nas quais o iso_code contenha "OWID"
df_covid.drop(df_covid.index[df_covid.iso_code.str.contains("OWID")].values, inplace = True)

# %% [markdown]
# Após a devida preparação dos dados, estaremos prontos para apresentar o resultado dos países com os maiores casos de **COVID-19**.

# %%
df_covid.groupby(['location']).total_cases.sum().sort_values(ascending = False)[:5]
# Out:
# location
# United States    6.956473e+10
# India            3.627330e+10
# Brazil           2.710612e+10
# China            2.492011e+10
# France           2.147175e+10
# Name: total_cases, dtype: float64

# %% [markdown]
# A seguir, examinaremos a proporção de casos em relação à quantidade total de casos registrados nesses países.

# %%
(df_covid.groupby(['location']).total_cases.sum()/df_covid.total_cases.sum() * 100).sort_values(ascending = False)[:5]
# Out:
# location
# United States    15.686589
# India             8.179495
# Brazil            6.112330
# China             5.619392
# France            4.841801
# Name: total_cases, dtype: float64

# %% [markdown]
# Plotaremos um gráfico de barras para a melhor visualização do resultado.

# %%
# Plotando gráficos para países com mais casos registrados até a data atual
fig, ax = plt.subplots()

# Obtendo os valores e índices dos países com mais casos
x = (df_covid.groupby(['location']).total_cases.sum().sort_values(ascending = False)[:5]).values
y = (df_covid.groupby(['location']).total_cases.sum().sort_values(ascending = False)[:5]).index

# Gráfico da quantidade de casos de COVID-19 por país
ax = sns.barplot(x = x, y = y, ax = ax, palette = "magma")
ax.grid(False)
ax.set_ylabel('Países')
ax.set_xlabel('Casos de COVID-19')
ax.set_title("Top 5 Países com Mais Casos de COVID-19");

plt.tight_layout()
plt.show()

# %%
# Calcular a soma dos casos dos cinco primeiros países
total_cases_top5 = df_covid.groupby(['location']).total_cases.sum().sort_values(ascending=False)[:5].sum()

# Calcular a soma de todos os casos
total_cases_all = df_covid['total_cases'].sum()

# Calcular a porcentagem
percentage = (total_cases_top5 / total_cases_all) * 100

print(f"A porcentagem que os cinco países com mais casos representam em relação ao restante é: {percentage:.2f}%")
# Out:
# A porcentagem que os cinco países com mais casos representam em relação ao restante é: 40.44%

# %% [markdown]
#  Podemos notar que os países que possuem os maiores números absolutos de casos totais são, respectivamente, **Estados Unidos, Índia, Brasil, China e Reino Unido**. Esses países em conjunto representam **40,44%** de todos os casos registrados.

# %% [markdown]
# Agora iremos analisar o **número de casos totais** apenas na última data disponível no conjunto de dados.

# %%
# ver última data no dataset
df_ld = df.dropna(subset=['total_cases'])
last_date = df_ld['date'].max()
print(f"A última data é {last_date.day}/{last_date.month}/{last_date.year}")
# Out:
# A última data é 16/8/2023

# %% [markdown]
# # 📍 **Quais são os países com maior número total de casos de COVID-19 até o dia 16/08/2023?**

# %%
df_covid.loc[df_covid.date == last_date].sort_values(by="total_cases", ascending=False).head(5)
# Out:
#        iso_code      continent       location       date  total_cases  \
# 315833      USA  North America  United States 2023-08-16  103436829.0
# 59496       CHN           Asia          China 2023-08-16   99301765.0
# 134725      IND           Asia          India 2023-08-16   44996335.0
# 101721      FRA         Europe         France 2023-08-16   38997490.0
# 109653      DEU         Europe        Germany 2023-08-16   38437756.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 315833        0.0               0.000     1127152.0         0.0
# 59496         NaN                 NaN      121628.0         0.0
# 134725        0.0              31.857      531922.0         0.0
# 101721        0.0               0.000      167985.0         0.0
# 109653        0.0               0.000      174979.0         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 315833                0.000  ...          24.6                     NaN
# ...

# %%
# visualizar os cinco principais países com mais casos na data atual
df_covid.loc[df_covid.date == last_date].groupby(['location']).total_cases.sum().sort_values(ascending = False)[:5]
# Out:
# location
# United States    103436829.0
# China             99301765.0
# India             44996335.0
# France            38997490.0
# Germany           38437756.0
# Name: total_cases, dtype: float64

# %%
# Plotando gráficos para tipos de imóveis
fig, ax1 = plt.subplots()

# gráfico da quantidade de casos de COVID-19 por países
ax1 = sns.barplot(x= (df_covid.loc[df_covid.date == last_date].groupby(['location']).total_cases.sum().sort_values(ascending = False)[:5]).values, y= (df_covid.loc[df_covid.date == last_date].groupby(['location']).total_cases.sum().sort_values(ascending = False)[:5]).index, ax = ax1, palette = "magma")
ax1.set_ylabel('Países')
ax1.set_xlabel('Casos de COVID-19')
ax1.set_title(f"Top 5 Países com Mais Casos de COVID-19) - {last_date.day}/{last_date.month}/{last_date.year}");

# Adicionando a porcentagem total na frente das barras
for index, value in enumerate(x):
    ax2.text(value + 1000, index, f'{(value/total_deaths)*100:.2f}%', va='center', color='black', fontweight='bold')

# %%
total_deaths = df_covid['total_deaths'].sum()  # Defina o total de óbitos
fig, ax2 = plt.subplots()

# atribuindo os valores e índices às variáveis
x = (df_covid.groupby(['location']).total_deaths.sum().sort_values(ascending = False)[:5]).values
y = (df_covid.groupby(['location']).total_deaths.sum().sort_values(ascending = False)[:5]).index

# gráfico da quantidade de casos de COVID-19 por países
ax2 = sns.barplot(x = x, y = y, ax = ax2, palette = "magma")
ax2.grid(False)
ax2.set_ylabel('Países')
ax2.set_xlabel('Mortes por COVID-19')
ax2.set_title(f" Os 5 países com o maior registro de óbitos até {last_date.day}/{last_date.month}/{last_date.year}")

# Adicionando a porcentagem total na frente das barras
for index, value in enumerate(x):
    ax2.text(value + 1000, index, f'{(value/total_deaths)*100:.2f}%', va='center', color='black', fontweight='bold')

plt.show()

# %% [markdown]
# Ao examinarmos a data mais recente disponível no conjunto de dados (16/08/2023), podemos identificar que os cinco países com a maior quantidade de casos de COVID-19 são os **Estados Unidos, China, Índia, França e Alemanha.**
#
# Por fim, vamos explorar a trajetória do número de casos no mundo até o momento atual. Isto será realizado por meio da criação de um gráfico de linhas e de um mapa, que proporcionarão uma visão panorâmica da distribuição de casos por região.

# %%
df_filtrado = df.loc[df.location == "World"]

fig = plt.gcf()
fig.set_size_inches(15, 5)
sns.set(style="whitegrid", palette = 'inferno')

ax = sns.lineplot(
    data=df_filtrado, x="date", y="total_cases",
);

ax.grid(False)
ax.set(xlabel='Data', ylabel='Número de casos')
ax.set_title(f"Casos de COVID-19 no mundo até {last_date.day}/{last_date.month}/{last_date.year}")
plt.show()

# %% [markdown]
# É evidente que ao longo do tempo, o número de casos registrados de COVID-19 tem aumentado em escala global.

# %% [markdown]
# # 📍 **Quais são os países com o maior registro de óbitos por COVID-19?**
#
# Vamos prosseguir de maneira análoga, analisando os países com as contagens mais elevadas de mortes relacionadas ao COVID-19.

# %%
df_covid.groupby(['location']).total_deaths.sum().sort_values(ascending = False)[:5]
# Out:
# location
# United States    890514697.0
# Brazil           598978525.0
# India            449453196.0
# Mexico           303959427.0
# Russia           289109213.0
# Name: total_deaths, dtype: float64

# %% [markdown]
# Agora, iremos analisar a proporção de óbitos em relação ao total de casos registrados nesses países.

# %%
(df_covid.groupby(['location']).total_deaths.sum()/df_covid.total_deaths.sum() * 100).sort_values(ascending = False)[:5]
# Out:
# location
# United States    16.072904
# Brazil           10.810966
# India             8.112183
# Mexico            5.486165
# Russia            5.218134
# Name: total_deaths, dtype: float64

# %%
total_deaths = df_covid['total_deaths'].sum()  # Defina o total de óbitos
fig, ax2 = plt.subplots()

# atribuindo os valores e índices às variáveis
x = (df_covid.groupby(['location']).total_deaths.sum().sort_values(ascending = False)[:5]).values
y = (df_covid.groupby(['location']).total_deaths.sum().sort_values(ascending = False)[:5]).index

# gráfico da quantidade de casos de COVID-19 por países
ax2 = sns.barplot(x = x, y = y, ax = ax2, palette = "magma")
ax2.grid(False)
ax2.set_ylabel('Países')
ax2.set_xlabel('Mortes por COVID-19')
ax2.set_title(f" Os 5 países com o maior registro de óbitos até {last_date.day}/{last_date.month}/{last_date.year}")

# Adicionando a porcentagem total na frente das barras
for index, value in enumerate(x):
    ax2.text(value + 1000, index, f'{(value/total_deaths)*100:.2f}%', va='center', color='black', fontweight='bold')

plt.show()

# %% [markdown]
# Os países com maior número de **mortes** relacionadas à doença são, respectivamente, os **Estados Unidos, Brasil, Índia, México e Russia**. É interessante notar que os três primeiros também se destacam pelo maior número de casos totais.
#
# Agora, vamos analisar os países com mais mortes registradas por **COVID-19** até a data de 16 de agosto de 2023. Posteriormente, observaremos o número total de mortes até a data atual.

# %%
df_covid.loc[df_covid.date == last_date].sort_values(by="total_deaths", ascending=False).head(5)
# Out:
#        iso_code      continent       location       date  total_cases  \
# 315833      USA  North America  United States 2023-08-16  103436829.0
# 40987       BRA  South America         Brazil 2023-08-16   37717062.0
# 134725      IND           Asia          India 2023-08-16   44996335.0
# 245876      RUS         Europe         Russia 2023-08-16   22983150.0
# 188406      MEX  North America         Mexico 2023-08-16    7633355.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 315833        0.0               0.000     1127152.0         0.0
# 40987         0.0               0.000      704659.0         0.0
# 134725        0.0              31.857      531922.0         0.0
# 245876        NaN                 NaN      399938.0         NaN
# 188406        0.0               0.000      334336.0         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 315833                0.000  ...          24.6                     NaN
# ...

# %%
# visualizar os cinco principais países com mais casos na data atual
df_covid.loc[df_covid.date == last_date].groupby(['location']).total_deaths.sum().sort_values(ascending = False)[:5]
# Out:
# location
# United States    1127152.0
# Brazil            704659.0
# India             531922.0
# Russia            399938.0
# Mexico            334336.0
# Name: total_deaths, dtype: float64

# %%
# Plotando gráficos
fig, ax1 = plt.subplots(figsize=(10, 5))

# Gráfico do número total de mortes por país
ax1 = sns.barplot(x=(df_covid.loc[df_covid.date == last_date].groupby(['location']).total_deaths.sum().sort_values(ascending=False)[:5]).values,
                  y=(df_covid.loc[df_covid.date == last_date].groupby(['location']).total_deaths.sum().sort_values(ascending=False)[:5]).index,
                  ax=ax1, palette="magma", orient="h")

ax1.grid(False)
ax1.set_xlabel('Número total de Mortes')
ax1.set_ylabel('Países')
ax1.set_title(f"Top 5 Países com Mais Mortes de COVID-19 até {last_date.day}/{last_date.month}/{last_date.year}")

plt.tight_layout()
plt.show()

# %% [markdown]
# Na última data registrada, os países com maior número de mortes foram os **Estados Unidos, Brasil, Índia, Rússia e México.**
#
# Agora, iremos analisar a evolução do número de mortes por COVID-19 **em todo o mundo até a data atual**, por meio da criação de um **gráfico de linhas**.

# %%
df_filtrado = df.loc[df.location == "World"]

fig = plt.gcf()
fig.set_size_inches(15, 5)
sns.set(style="whitegrid", palette = 'magma')

ax = sns.lineplot(
    data=df_filtrado, x="date", y="total_deaths",
);

ax.grid(False)
ax.set(xlabel='Data', ylabel='Número de mortes')
ax.set_title(f"Mortes por COVID-19 no mundo até {last_date.day}/{last_date.month}/{last_date.year}")
plt.show()

# %% [markdown]
# # 📍 Quais são os países com o maior número de pessoas vacinadas?
#
# Vamos agora verificar os cinco países que possuem o maior número de pessoas vacinadas (com pelo menos a primeira dose), lembrando que estamos considerando valores absolutos.

# %%
df_covid.groupby(['location']).people_vaccinated.sum().sort_values(ascending = False)[:5]
# Out:
# location
# India            7.079611e+11
# United States    1.879005e+11
# Brazil           9.282500e+10
# Japan            6.724668e+10
# China            5.787098e+10
# Name: people_vaccinated, dtype: float64

# %% [markdown]
# Agora vamos analisar a porcentagem em relação ao conjunto de dados como um todo.

# %%
(df_covid.groupby(['location']).people_vaccinated.sum()/df_covid.people_vaccinated.sum() * 100).sort_values(ascending = False)[:5]
# Out:
# location
# India            38.492855
# United States    10.216421
# Brazil            5.047028
# Japan             3.656298
# China             3.146528
# Name: people_vaccinated, dtype: float64

# %%
# Plotando gráficos para países com maior número de pessoas vacinadas
fig, ax3 = plt.subplots()

# atribuindo os valores e índices às variáveis
x = (df_covid.groupby(['location']).people_vaccinated.sum().sort_values(ascending = False)[:5]).values
y = (df_covid.groupby(['location']).people_vaccinated.sum().sort_values(ascending = False)[:5]).index

# gráfico da quantidade de casos de COVID-19 por países
ax3 = sns.barplot(x = x, y = y, ax = ax3, palette = "magma")
ax3.grid(False)
ax3.set_ylabel('Países')
ax3.set_xlabel('Número de Pessoas Vacinadas')
ax3.set_title("Relação entre Países e População Vacinada - Números absolutos");

# %% [markdown]
# Os cinco países com mais pessoas vacinadas são: **Índia, Estados Unidos, Brasil, Japão e China.**

# %% [markdown]
# # 📍 Há Correlação entre População Idosa e Mortes por COVID-19?
#
# Compreender a relação entre a parcela da população com 65 anos ou mais e o número total de mortes por COVID-19 é fundamental para entender os fatores de risco associados à gravidade da doença. Embora a maioria dos casos apresente sintomas leves a moderados, certos grupos enfrentam um risco maior de manifestações clínicas graves, incluindo idosos, indivíduos do sexo masculino e pessoas com comorbidades.
#
# A influência da idade é especialmente significativa, sendo um dos principais fatores de risco para casos graves e desfechos negativos da COVID-19. Para avaliar essa relação, utilizamos o coeficiente de correlação, uma medida estatística que quantifica a associação entre duas variáveis.
#
# "O coeficiente de correlação é uma métrica estatística que avalia a relação entre duas variáveis, revelando o grau de associação à medida que o valor de uma variável se modifica."
#
# * Iremos plotar uma **matriz de correlação** para observar a medida obtida entre as variáveis `aged_65_older` e `total_deaths`.
# * Como o total de mortes é um valor absoluto, enquanto a quantidade de pessoas acima de 65 anos é uma parcela da população, para correlacioná-los iremos transformar a variável `total_deaths`, dividindo-a pelo número da população, criando a variável `percentual_mortes`.
# * Vamos relacionar o percentual de mortes (em relação à população total) com o percentual de pessoas com 65 anos ou mais.
# * Depois, faremos uma análise semelhante para as variáveis `gdp_per_capita` e `total_deaths_per_million`. Seguiremos os seguintes passos:
#
# Os passos a seguir guiam nossa análise:
#
# 1. Criação da matriz de correlação.
# 2. Exibição dos resultados obtidos.
# 3. Realização de um teste de hipóteses.
# 4. Plotagem de um gráfico de correlação.
# 5. Plotagem de um gráfico de dispersão.
#
# Ao final, nossa análise proporcionará uma visão mais clara sobre a associação entre a parcela idosa da população e o número de mortes por COVID-19.

# %%
# fazer uma cópia do dataframe
df_corr = df_covid
df_corr.dropna(subset=['total_deaths'], inplace = True)

# criar variável que é o percentual de mortes por poupulação
div_column = df_corr['total_deaths']/df_corr['population']
df_corr['percentual_mortes'] = div_column

# criar uma matriz de correlação
corr_df = df_corr[['aged_65_older','percentual_mortes', 'gdp_per_capita', 'total_deaths_per_million']].corr(method='pearson');
# mostrar a matriz de correlação
display(corr_df);
# Out:
#                           aged_65_older  percentual_mortes  gdp_per_capita  \
# aged_65_older                  1.000000           0.472952        0.502833
# percentual_mortes              0.472952           1.000000        0.183923
# gdp_per_capita                 0.502833           0.183923        1.000000
# total_deaths_per_million       0.473442           0.999984        0.184230
#
#                           total_deaths_per_million
# aged_65_older                             0.473442
# percentual_mortes                         0.999984
# gdp_per_capita                            0.184230
# total_deaths_per_million                  1.000000

# %%
# plotar o gráfico de correlação
sns.heatmap(corr_df, fmt='.2f',square = True, annot = True);

# %% [markdown]
# Vamos conduzir um teste de hipóteses com um nível de significância de 5% para determinar se há uma correlação entre `aged_65_older` e `percentual_mortes`.
#
# Teste de Hipóteses — `aged_65_older` e `percentual_mortes`
#
# ρ = coeficiente de correlação linear de Pearson populacional
#
# **Hipótese Nula H0** : ρ = 0
#
# A hipótese nula afirma que não existe uma relação linear significativa entre a parcela da população com 65 anos ou mais e o percentual de mortes. Em outras palavras, o coeficiente de correlação linear entre essas variáveis é zero.
#
# **Hipótese Alternativa HA **: ρ ≠ 0
#
# A hipótese alternativa sugere que existe um coeficiente de correlação linear significativo entre as duas variáveis.

# %%
# variáveis necessárias para o cálculo
r = 0.473442
r_2 = r ** 2
n = df_covid.shape[0]
print("R = ",r)
print("R² = ",round(r_2 * 100,2), "%")
print("N = ", n)
# Out:
# R =  0.473442
# R² =  22.41 %
# N =  258768

# %% [markdown]
# A variável `aged_65_older` afeta o percentual de mortes em **22.41%**.

# %%
# T-Calculado
tc = (r * math.sqrt(n-2))/math.sqrt(1 - r_2)
print("Tc: ", round(tc,4))
# Out:
# Tc:  273.4203

# %%
# graus de liberdade n-2 com 5% de signficância.
t = stats.t.ppf(1-0.025, n - 2)
print ("Valor na t de student: ", round(t,2))
# Out:
# Valor na t de student:  1.96

# %% [markdown]
# Uma vez que **tc > t**, rejeitamos a hipótese nula e concluímos que, com um nível de significância de **5%**, há uma correlação positiva entre o número total de pessoas com mais de 65 anos e o percentual de mortes.
#
# A **próxima etapa** envolve a criação de um gráfico de dispersão que relaciona essas duas variáveis a partir do mês de agosto.

# %%
# Filtrando os dados a partir da última data disponível
df_filtrado = df_covid.loc[df_covid.date >= '2023-08-16']

# Criando a figura do gráfico e ajustando o tamanho
fig = plt.gcf()
fig.set_size_inches(15, 8)

# Plotando um gráfico de dispersão com paleta colorida
ax = sns.scatterplot(data=df_filtrado, x="aged_65_older", y="percentual_mortes", hue="continent", palette="pastel", s=100)

# Definindo os rótulos dos eixos
ax.set(xlabel='Parcela da População com mais de 65 anos', ylabel='Percentual de Mortes')

# Definindo o título do gráfico
ax.set_title(f"Relação entre Parcela da População com mais de 65 anos e Percentual de Mortes — {last_date.month}/{last_date.year}")

# Desativando as grades no gráfico
ax.grid(False)

# Exibindo a legenda
ax.legend(title='Continente')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Observa-se de maneira geral que à medida que a proporção da população com idade acima de 65 anos aumenta, o percentual total de mortes também tende a aumentar.
#
# Agora, investigaremos a possível correlação entre a variável `gdp_per_capita` (PIB per capita) e `total_deaths_per_million` (número total de mortes por milhão de habitantes). Para isso, realizaremos um teste de hipóteses com um nível de significância de 5% e plotaremos um gráfico de dispersão. A variável `gdp_per_capita` representa a economia de um país, permitindo-nos explorar a relação entre a saúde econômica e o número de mortes.
#
# **Teste de Hipóteses — gdp_per_capita e total_deaths_per_million**
# ρ = coeficiente de correlação linear de Pearson populacional
#
# - **Hipótese Nula H0 : ρ = 0**
# A hipótese nula assume que não existe relação linear entre o PIB per capita e o número total de mortes. Ou seja, o coeficiente de correlação linear entre essas duas variáveis é nulo.
#
# - **Hipótese Alternativa HA : ρ ≠ 0**
# A hipótese alternativa sugere que existe uma correlação linear significativa entre o PIB per capita e o número total de mortes.
#
# Vamos prosseguir com a análise plotando um gráfico de dispersão para visualizar melhor essa possível relação.

# %%
# variáveis necessárias para o cálculo
r = 0.183923
r_2 = r ** 2
n = df_covid.shape[0]
print("R = ",r)
print("R² = ",round(r_2 * 100,2), "%")
print("N = ", n)
# Out:
# R =  0.183923
# R² =  3.38 %
# N =  258768

# %% [markdown]
# Pode-se observar que a variável` gdp_per_capita` afeta o número total de mortes em 3.38%

# %%
# T-Calculado
tc = (r * math.sqrt(n-2))/math.sqrt(1 - r_2)
print("Tc: ", round(tc,4))
# Out:
# Tc:  95.1836

# %%
# graus de liberdade n-2 com 5% de signficância.
t = stats.t.ppf(1-0.025, n - 2)
print ("Valor na t de student: ", round(t,2))
# Out:
# Valor na t de student:  1.96

# %% [markdown]
# Dado que o valor de tc é maior que o valor crítico t, rejeitamos a hipótese nula. Concluímos, portanto, que com um nível de significância de 5%, há uma correlação positiva entre o PIB do país e o número total de mortes. Em outras palavras, há indícios estatísticos de que o crescimento do PIB per capita está associado a um aumento no número total de mortes por milhão de habitantes.

# %%
df_filtrado = df_covid.loc[df_covid.date >= '2023-08-16']
fig = plt.gcf()
fig.set_size_inches(15, 8)
ax = sns.scatterplot(data=df_filtrado, x="gdp_per_capita", y="total_deaths_per_million", hue="continent", palette="pastel", s=100)
ax.set(xlabel='PIB (Produto Interno Bruto)', ylabel='Número total de mortes por milhão de habitantes')
ax.set_title(f"Relação entre PIB e Número Total de Mortes por Milhão de Habitantes — {last_date.month}/{last_date.year}")
ax.grid(False)
plt.show()

# %% [markdown]
# ## Exploração de Dados para o BRASIL

# %% [markdown]
# ![images (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Nesta fase, concentraremos nossa análise no contexto brasileiro e procuraremos responder às seguintes questões:
#
# 1. Qual foi a data do primeiro registro de caso de COVID-19 no Brasil?
# 2. Qual foi a data do primeiro registro de morte por COVID-19 no Brasil?
# 3. Gráfico da média móvel dos casos e óbitos por COVID-19 no Brasil.
# 4. Gráfico de linha mostrando a evolução do número de pessoas vacinadas no Brasil.
# 5. Gráfico de linha exibindo a progressão das doses de reforço administradas.
# 6. Gráfico de dispersão relacionando o percentual de vacinados com o percentual de óbitos.
# 7. Comparação da média móvel de casos e óbitos no Brasil com o cenário global.

# %%
# criar uma cópia do dataset original apenas com dados do Brasil
df_brasil = df.loc[df.location == "Brazil"].copy()

# %%
# mostrar as cinco primeiras entradas
df_brasil.head()
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 39666      BRA  South America   Brazil 2020-01-03          NaN        0.0
# 39667      BRA  South America   Brazil 2020-01-04          NaN        0.0
# 39668      BRA  South America   Brazil 2020-01-05          NaN        0.0
# 39669      BRA  South America   Brazil 2020-01-06          NaN        0.0
# 39670      BRA  South America   Brazil 2020-01-07          NaN        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 39666                 NaN           NaN         0.0                  NaN  ...
# 39667                 NaN           NaN         0.0                  NaN  ...
# 39668                 NaN           NaN         0.0                  NaN  ...
# 39669                 NaN           NaN         0.0                  NaN  ...
# 39670                 NaN           NaN         0.0                  NaN  ...
#
# ...

# %%
# verificar a quantidade valores ausentes
(df_brasil.isnull().sum() / df_brasil.shape[0]).sort_values(ascending=True)
# Out:
# iso_code                                      0.000000
# population_density                            0.000000
# median_age                                    0.000000
# aged_65_older                                 0.000000
# aged_70_older                                 0.000000
# gdp_per_capita                                0.000000
# extreme_poverty                               0.000000
# cardiovasc_death_rate                         0.000000
# diabetes_prevalence                           0.000000
# female_smokers                                0.000000
# male_smokers                                  0.000000
# hospital_beds_per_thousand                    0.000000
# human_development_index                       0.000000
# population                                    0.000000
# life_expectancy                               0.000000
# continent                                     0.000000
# location                                      0.000000
# ...

# %%
# exibir primeiro caso confirmado de COVID-19 no Brasil
df_brasil.loc[df_brasil['total_cases'] == df_brasil['total_cases'].min()]['date'].min()
# Out:
# Timestamp('2020-02-27 00:00:00')

# %% [markdown]
# Timestamp('2020-02-26 00:00:00')
#
# O primeiro caso confirmado de COVID-19 no Brasil ocorreu em 26 de fevereiro de 2020.
#
# Agora, iremos analisar as datas mínimas e máximas de registros no conjunto de dados.

# %%
# exibir a data máxima e mínima de registro no Brasil
print(f'Data inicial dos registros: {df_brasil.date.min()}')
print(f'Data final dos registros: {df_brasil.date.max()}')
# Out:
# Data inicial dos registros: 2020-01-03 00:00:00
# Data final dos registros: 2023-08-16 00:00:00

# %% [markdown]
# A seguir, analisaremos gráficos de linhas que representam a média móvel de casos de COVID-19 no Brasil até a data atual, bem como a média móvel de mortes. A média móvel é calculada considerando a média dos casos ou mortes nos últimos 7 dias.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(17, 8))

df_brasil_clean_new_cases_smoothed = df_brasil.dropna(subset=['new_cases_smoothed'])
df_brasil_clean_new_deaths_smoothed = df_brasil.dropna(subset=['new_deaths_smoothed'])

ax1.grid(False)
ax2.grid(False)

ax1.plot(df_brasil_clean_new_cases_smoothed['date'], df_brasil_clean_new_cases_smoothed['new_cases_smoothed'], label='Casos Confirmados')
last_date = df_brasil_clean_new_cases_smoothed['date'].max()
ax1.set_title(f"Média móvel de casos de COVID-19 no Brasil até {last_date.day}/{last_date.month}/{last_date.year}", fontsize=20);


ax2.plot(df_brasil_clean_new_deaths_smoothed['date'], df_brasil_clean_new_deaths_smoothed['new_deaths_smoothed'], label='Mortes')
last_date = df_brasil_clean_new_deaths_smoothed['date'].max()
ax2.set_title(f"Média móvel de mortes de COVID-19 no Brasil até {last_date.day}/{last_date.month}/{last_date.year}", fontsize=20);


plt.tight_layout(pad = 3.0);

# %% [markdown]
# É notável que a **média móvel de casos** atingiu seu ponto mais alto a partir de janeiro de 2022. Esse aumento pode ser atribuído à variante **ômicron**, que resultou em um aumento significativo nos casos no país. A variante ômicron foi identificada pela primeira vez no Brasil em 30 de novembro de 2021, e esse aumento pode ter sido agravado por medidas de flexibilização do distanciamento social e pela realização de eventos festivos no final do ano. No entanto, esse aumento não se reflete na média móvel de mortes.
#
# A próxima análise consistirá na observação de gráficos de linhas que representam a porcentagem de pessoas que receberam pelo menos a primeira dose de vacina no Brasil, bem como as doses de reforço aplicadas.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1,figsize=(15, 8))


df_brasil_clean_people_vaccinated_per_hundred = df_brasil.dropna(subset=['people_vaccinated_per_hundred'])
df_brasil_clean_total_boosters_per_hundred = df_brasil.dropna(subset=['total_boosters_per_hundred'])

ax1.grid(False)
ax2.grid(False)

ax1.plot(df_brasil_clean_people_vaccinated_per_hundred['date'], df_brasil_clean_people_vaccinated_per_hundred['people_vaccinated_per_hundred'])
ax1.set_title(f"Porcentagem de pessoas com ao menos a 1º dose no Brasil", fontsize=18);

ax2.plot(df_brasil_clean_total_boosters_per_hundred['date'], df_brasil_clean_total_boosters_per_hundred['total_boosters_per_hundred'])
ax2.set_title(f"Porcentagem de doses de reforço aplicadas", fontsize=18);


plt.tight_layout(pad = 3.0);

# %% [markdown]
# É evidente que ao longo do tempo, houve um aumento na porcentagem de pessoas que receberam a primeira dose da vacina, bem como na porcentagem das doses de reforço aplicadas.
#
# Analisando os gráficos acima, é perceptível que o aumento no número de casos de COVID-19 não foi diretamente refletido no aumento do número de mortes. Além disso, simultaneamente ao aumento dos casos, houve um crescimento na quantidade de pessoas vacinadas. Essa correlação aponta para a possibilidade de que as vacinas possam ter contribuído para a redução da taxa de mortalidade.
#
# A fim de investigar uma possível correlação entre essas variáveis, será construída uma matriz de correlação entre o percentual de mortes em relação ao número de casos e o percentual de vacinados em relação à população.

# %%
# fazer uma cópia do dataframe
df_corr = df_brasil

# criar variável que é o número de mortes por número de casos
div_column = df_corr['total_deaths']/df_corr['total_cases']
df_corr['percentual_mortes'] = div_column

# criar variável que é o número de pessoas vacinadas pela população
div_column = df_corr['people_vaccinated']/df_corr['population']
df_corr['percentual_vacinados'] = div_column

# criar uma matriz de correlação
corr_df = df_corr[['percentual_mortes', 'percentual_vacinados']].corr(method='pearson');

# mostrar a matriz de correlação
display(corr_df);
# Out:
#                       percentual_mortes  percentual_vacinados
# percentual_mortes              1.000000             -0.522036
# percentual_vacinados          -0.522036              1.000000

# %% [markdown]
# Identificamos uma **correlação negativa**, o que sugere que quanto **maior** for o **percentual de pessoas vacinada**s, **menor** tende a ser o **percentual de mortes**.
#
# Para **visualizar** essa relação de maneira mais clara, vamos criar um **gráfico de dispersão** com ambas as variáveis, a partir de janeiro de 2021. Isso nos permitirá visualizar como a evolução da vacinação está associada à variação das taxas de mortalidade.

# %%
df_filtrado = df_brasil.loc[df_brasil.date >= '2022-01-01']
fig = plt.gcf()

fig.set_size_inches(15, 8)

ax = sns.scatterplot(data=df_filtrado, x="percentual_vacinados", y="percentual_mortes", hue="location",  palette="magma", s = 100)
ax.set(xlabel='Percentual de vacinados', ylabel='Percentual de mortes')
ax.set_title("Percentual de vacinados x Percentual de mortes")
ax.grid(False)
plt.show()

# %% [markdown]
# Para concluir nossa análise, vamos examinar um gráfico que compara a média móvel de mortes no Brasil e no mundo ao longo do tempo. Isso nos dará uma visão abrangente das tendências de mortalidade em ambos os cenários e nos ajudará a contextualizar a situação do Brasil em relação à situação global.

# %%
fig, ax = plt.subplots(figsize=(20, 8))

mundo = df.loc[df.location == 'World'][['date', 'new_cases_smoothed_per_million']]
df_brasil_cleaned = df_brasil.dropna(subset=['new_cases_smoothed_per_million'])

ax.grid(False)
ax.plot(df_brasil_cleaned['date'], df_brasil_cleaned['new_cases_smoothed_per_million'], label = 'Brasil')
ax.plot(mundo['date'], mundo['new_cases_smoothed_per_million'], c = 'pink', label = 'Mundo')

ax.set_title('Média Móvel no Brasil vs Mundo', fontsize = 20)
leg = plt.legend(loc='upper left', prop={'size': 20})

plt.tight_layout(pad = 3.0);

# %% [markdown]
# ![conclusao.png](data:image/png;base64,...)

# %% [markdown]
# # Considerações Finais ✨🔍📊
#
# Esta análise forneceu insights tanto a nível global quanto local, utilizando um conjunto de dados fornecido pelo Our World in Data, que incluía informações sobre o número de casos e mortes em cada país, a parcela da população com idade acima de 65 anos, o PIB do país, entre outros dados relevantes. É importante ressaltar que essa análise é uma abordagem superficial e exploratória, focada no estudo, e os números foram observados em termos absolutos, o que pode influenciar os resultados finais.
#
# Algumas observações podem ficar desatualizadas devido aos relatórios contínuos da COVID-19. No entanto, com base na análise até 12 de maio de 2022, podemos tirar as seguintes conclusões:
#
# - Os países com mais casos absolutos de COVID-19 são, em ordem: Estados Unidos, Índia, Brasil, França e Reino Unido. Juntos, eles representam 45% de todos os casos registrados globalmente.
# - No último registro disponível, os países com mais casos são: Estados Unidos, Índia, Brasil, França e Alemanha.
# - Os países com mais mortes absolutas por COVID-19 são: Estados Unidos, Brasil, Índia, México e Peru.
# - No último registro disponível, os países com mais mortes registradas são: Estados Unidos, Brasil, Índia, Rússia e México.
# - Os países com o maior número absoluto de pessoas vacinadas são: Índia, Estados Unidos, Brasil, Indonésia e China.
# - A variável aged_65_older, que representa a parcela da população com mais de 65 anos, tem uma correlação de 15.06% com o número total de mortes.
# - A variável gdp_per_capita, que representa o PIB do país, tem uma correlação de 2.29% com o número total de mortes.
# - O primeiro caso confirmado de COVID-19 no Brasil ocorreu em 26 de fevereiro de 2020.
# - A primeira morte por COVID-19 no Brasil foi registrada em 17 de março de 2020.
# - A média móvel de casos no país teve um pico devido à variante ômicron, mas a média móvel de mortes não acompanhou um aumento considerável.
# - A porcentagem de pessoas que receberam pelo menos a primeira dose da vacina e a quantidade de doses de reforço aplicadas têm aumentado ao longo do tempo.
# - Há uma correlação negativa entre o aumento da porcentagem de pessoas vacinadas e a diminuição do percentual de mortes.
#
# Esta análise oferece uma visão inicial dos dados disponíveis e pode servir como ponto de partida para investigações mais aprofundadas sobre os fatores que influenciam a propagação e o impacto da COVID-19 em diferentes países.
